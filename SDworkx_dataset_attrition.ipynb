# %%
from google.colab import drive

drive.mount('/content/gdrive/', force_remount = True)
# Out:
# Mounted at /content/gdrive/

# %%
df = pd.read_csv('/content/gdrive/My Drive/WLDS/hackathon/sdworkx/data_set/selected/data.csv')

# %%
import pandas as pd
import numpy as np
import seaborn as sn
import matplotlib.pyplot as plt

# %%
df.head()
# Out:
#    Age Attrition  ... YearsSinceLastPromotion  YearsWithCurrManager
# 0   41       Yes  ...                       0                     5
# 1   49        No  ...                       1                     7
# 2   37       Yes  ...                       0                     0
# 3   33        No  ...                       3                     0
# 4   27        No  ...                       2                     2
#
# [5 rows x 35 columns]

# %%
df.isna().sum()
# Out:
# Age                         0
# Attrition                   0
# BusinessTravel              0
# DailyRate                   0
# Department                  0
# DistanceFromHome            0
# Education                   0
# EducationField              0
# EmployeeCount               0
# EmployeeNumber              0
# EnvironmentSatisfaction     0
# Gender                      0
# HourlyRate                  0
# JobInvolvement              0
# JobLevel                    0
# JobRole                     0
# JobSatisfaction             0
# MaritalStatus               0
# MonthlyIncome               0
# MonthlyRate                 0
# NumCompaniesWorked          0
# Over18                      0
# OverTime                    0
# PercentSalaryHike           0
# PerformanceRating           0
# RelationshipSatisfaction    0
# StandardHours               0
# StockOptionLevel            0
# TotalWorkingYears           0
# TrainingTimesLastYear       0
# WorkLifeBalance             0
# ...

# %%
df.describe
# Out:
# <bound method NDFrame.describe of       Age Attrition  ... YearsSinceLastPromotion  YearsWithCurrManager
# 0      41       Yes  ...                       0                     5
# 1      49        No  ...                       1                     7
# 2      37       Yes  ...                       0                     0
# 3      33        No  ...                       3                     0
# 4      27        No  ...                       2                     2
# ...   ...       ...  ...                     ...                   ...
# 1465   36        No  ...                       0                     3
# 1466   39        No  ...                       1                     7
# 1467   27        No  ...                       0                     3
# 1468   49        No  ...                       0                     8
# 1469   34        No  ...                       1                     2
#
# [1470 rows x 35 columns]>

# %%
sn.countplot(df['Attrition'])
# Out:
# /usr/local/lib/python3.6/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %%
plt.subplots(figsize=(12,4))
sn.countplot(x='Age', hue='Attrition', data=df, palette = 'colorblind')

# %%
plt.figure(figsize=(14,14))
sn.heatmap(df.corr(), annot=True, fmt='.0%' )

# %%
f, ax = plt.subplots(3,4, figsize=(20, 15),dpi = 120,squeeze=False)

sns.countplot(x='EnvironmentSatisfaction',hue='JobSatisfaction', data=df,ax=ax[0,0])
sns.countplot(x='JobInvolvement',hue='JobSatisfaction', data=df,ax=ax[0,1])
sns.countplot(x='DistanceFromHome',hue='JobSatisfaction', data=df,ax=ax[0,2])
sns.countplot(x='RelationshipSatisfaction',hue='JobSatisfaction', data=df,ax=ax[0,3])
sns.countplot(x='StandardHours',hue='JobSatisfaction', data=df,ax=ax[1,0])
sns.countplot(x='JobRole',hue='JobSatisfaction', data=df,ax=ax[1,1])
sns.countplot(x='JobLevel',hue='JobSatisfaction', data=df,ax=ax[1,2])
sns.countplot(x='EducationField',hue='JobSatisfaction', data=df,ax=ax[1,3])
sns.countplot(x='Age',hue='JobSatisfaction', data=df,ax=ax[2,0])
sns.countplot(x='BusinessTravel',hue='JobSatisfaction', data=df,ax=ax[2,1])
sns.countplot(x='Gender',hue='JobSatisfaction', data=df,ax=ax[2,2])
sns.countplot(x='WorkLifeBalance',hue='JobSatisfaction', data=df,ax=ax[2,3])

ax[0,0].set_xticklabels(ax[0,0].get_xticklabels(), rotation=90, ha='right')
ax[0,1].set_xticklabels(ax[0,1].get_xticklabels(), rotation=90, ha='right')
ax[0,2].set_xticklabels(ax[0,2].get_xticklabels(), rotation=90, ha='right')
ax[0,3].set_xticklabels(ax[0,3].get_xticklabels(), rotation=90, ha='right')
ax[1,0].set_xticklabels(ax[1,0].get_xticklabels(), rotation=90, ha='right')
ax[1,1].set_xticklabels(ax[1,1].get_xticklabels(), rotation=90, ha='right')
ax[1,2].set_xticklabels(ax[1,2].get_xticklabels(), rotation=90, ha='right')
ax[1,3].set_xticklabels(ax[1,3].get_xticklabels(), rotation=90, ha='right')
ax[2,0].set_xticklabels(ax[2,0].get_xticklabels(), rotation=90, ha='right')
ax[2,1].set_xticklabels(ax[2,1].get_xticklabels(), rotation=90, ha='right')
ax[2,2].set_xticklabels(ax[2,2].get_xticklabels(), rotation=90, ha='right')
ax[2,3].set_xticklabels(ax[2,3].get_xticklabels(), rotation=90, ha='right')


f.tight_layout()
f.show()
